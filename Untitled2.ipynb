# %%
import dhlab as dh
import pandas as pd
import dhlab.api.dhlab_api as api

# %%
corpus = pd.read_csv('norske_aviser.csv', index_col = 0)

# %%
corpus
# Out:
#          dhlabid                                                urn  \
# 0    100039294.0                URN:NBN:no-nb_digibok_2007073004005
# 1    100003861.0                URN:NBN:no-nb_digibok_2007041901045
# 0    203307348.0  URN:NBN:no-nb_digavis_decorahposten_null_null_...
# 1    202125657.0  URN:NBN:no-nb_digavis_decorahposten_null_null_...
# 2    202125057.0  URN:NBN:no-nb_digavis_decorahposten_null_null_...
# ..           ...                                                ...
# 897  203461740.0  URN:NBN:no-nb_digavis_vinland_null_null_197307...
# 898  203461629.0  URN:NBN:no-nb_digavis_vinland_null_null_197103...
# 899  203461064.0  URN:NBN:no-nb_digavis_vinland_null_null_195912...
# 900  203461508.0  URN:NBN:no-nb_digavis_vinland_null_null_196809...
# 901  203461729.0  URN:NBN:no-nb_digavis_vinland_null_null_197305...
#
#                                                  title  doctype   timestamp  \
# ...

# %%
import requests

# %%
r=requests.post(f"{api.BASE_URL}/frequencies", json = {'urns':list(corpus.urn.values), 'cutoff':5, 'words':['utenordmenn','og', 'i', '.']})

# %%
df = pd.DataFrame(r.json())

# %%
df.columns = ['urn', 'word', 'freq', 'doc']

# %%
df[df['word'] =='utenordmenn'].sum()
# Out:
# urn     URN:NBN:no-nb_digavis_nordisktidende_null_null...
# word    utenordmennutenordmennutenordmennutenordmennut...
# freq                                                    8
# doc                                                382484
# dtype: object
